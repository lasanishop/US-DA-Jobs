# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'/kaggle/input/data-related-jobs-in-us/Data_related_jobs_glassdoor.csv', encoding='latin-1')

# %%
df
# Out:
#                              company  \
# 0                          Microsoft
# 1     UT Southwestern Medical Center
# 2                             Notion
# 3                         Net2Aspire
# 4                     Ntropy Network
# ...                              ...
# 2079                         YouTube
# 2080              Hunter Engineering
# 2081     precision technologies corp
# 2082     Argonne National Laboratory
# 2083            Colossal Biosciences
#
#                                               job title       location  \
# 0                              Data & Applied Scientist    Redmond, WA
# 1           Data Scientist or Bioinformatician (remote)         Remote
# 2                                Data Scientist, Growth   New York, NY
# 3                                    Jr. Data Scientist         Remote
# 4                                        Data Scientist         Remote
# ...                                                 ...            ...
# ...

# %%
df.columns
# Out:
# Index(['company', 'job title', 'location', 'job description',
#        'salary estimate', 'company_size', 'company_type', 'company_sector',
#        'company_industry', 'company_founded', 'company_revenue', 'hourly',
#        'rating', 'python_yn', 'spark_yn', 'azure_yn', 'aws_yn', 'excel_yn',
#        'machine_learning_yn', 'job_simpl', 'seniority', 'description_len',
#        'company_age'],
#       dtype='object')

# %%
df.head()
# Out:
#                           company  \
# 0                       Microsoft
# 1  UT Southwestern Medical Center
# 2                          Notion
# 3                      Net2Aspire
# 4                  Ntropy Network
#
#                                      job title      location  \
# 0                     Data & Applied Scientist   Redmond, WA
# 1  Data Scientist or Bioinformatician (remote)        Remote
# 2                       Data Scientist, Growth  New York, NY
# 3                           Jr. Data Scientist        Remote
# 4                               Data Scientist        Remote
#
#                                      job description  salary estimate  \
# 0  Microsoft 365 is a key part of the companys c...           123486
# 1  Center Information:\nThe Quantitative Biomedic...            93500
# 2  About Us:\nWe're on a mission to make it possi...           137853
# 3  ? Apply Statistical and Machine Learning metho...            72500
# ...

# %%
df[df['company'].str.len() > 50]
# Out:
#                                                 company  \
# 126   Artificial Intelligence Labs at the American A...
# 1418  bitsIO Inc., 920 South Spring St, Ste 1200, Sp...
#
#                                               job title  location  \
# 126   Data Scientist / Engineer for Digital Health (...    Remote
# 1418                                      Data Engineer  Illinois
#
#                                         job description  salary estimate  \
# 126   This is a part-time and remote job only for da...           180000
# 1418  This is a remote position.\nKey responsibiliti...           145000
#
#      company_size company_type company_sector company_industry  \
# 126           NaN          NaN            NaN              NaN
# 1418          NaN          NaN            NaN              NaN
#
#       company_founded  ... python_yn  spark_yn  azure_yn  aws_yn  excel_yn  \
# 126               NaN  ...         1         1         0       1         0
# ...

# %%
# Apply str.lower() if str.len() > 20
df['main'] = df['company'].apply(lambda x: x.lower() if len(x) > 30 else x)
df['main']
# Out:
# 0                            Microsoft
# 1       UT Southwestern Medical Center
# 2                               Notion
# 3                           Net2Aspire
# 4                       Ntropy Network
#                      ...
# 2079                           YouTube
# 2080                Hunter Engineering
# 2081       precision technologies corp
# 2082       Argonne National Laboratory
# 2083              Colossal Biosciences
# Name: main, Length: 2084, dtype: object

# %%
df.filter(items=['company','job title','salary estimate'])
# Out:
#                              company  \
# 0                          Microsoft
# 1     UT Southwestern Medical Center
# 2                             Notion
# 3                         Net2Aspire
# 4                     Ntropy Network
# ...                              ...
# 2079                         YouTube
# 2080              Hunter Engineering
# 2081     precision technologies corp
# 2082     Argonne National Laboratory
# 2083            Colossal Biosciences
#
#                                               job title  salary estimate
# 0                              Data & Applied Scientist           123486
# 1           Data Scientist or Bioinformatician (remote)            93500
# 2                                Data Scientist, Growth           137853
# 3                                    Jr. Data Scientist            72500
# 4                                        Data Scientist           155000
# ...                                                 ...              ...
# ...

# %%
filtered_df = df[df['salary estimate'] > 110000]

# Select the desired columns
result = filtered_df[['company', 'job title', 'salary estimate']]

# Display the result
result
# Out:
#                 company                                          job title  \
# 0             Microsoft                           Data & Applied Scientist
# 2                Notion                             Data Scientist, Growth
# 4        Ntropy Network                                     Data Scientist
# 13    STEPS TALENT, LLC         Data Scientist - 3 positions - 100% remote
# 15           Salesforce          Staff Data Scientist, Customer Experience
# ...                 ...                                                ...
# 2069                GRI                          Machine Learning Engineer
# 2070               Bose                 Machine Learning Research Engineer
# 2075         CVS Health  Senior Machine Learning Engineer ( Python , ML...
# 2076     Morgan Stanley                        Machine Learning Researcher
# 2079            YouTube  Staff Software Engineer, Machine Learning, You...
#
#       salary estimate
# 0              123486
# ...

# %%
df['location'].str.contains('remote', case=False).sum()
# Out:
# 565

# %%
df.loc[(df['company'].str.startswith('M')) & (df['salary estimate'] > 150000)]
# Out:
#                  company              job title      location  \
# 76             Match Inc         Data Scientist        Remote
# 590            Microsoft  Senior Data Scientist   Redmond, WA
# 814            Microsoft  Senior Data Scientist   Redmond, WA
# 1386           Manrco In          Data Engineer        Remote
# 1412  Medidata Solutions   Senior Data Engineer  New York, NY
# 1885            Measured       SVP, Engineering   Chicago, IL
#
#                                         job description  salary estimate  \
# 76    Job Title : Data Scientist\nLocation : San Fra...           190000
# 590   As part of the Ecosystems business within C+E,...           165200
# 814   As part of the Ecosystems business within C+E,...           165200
# 1386  Data Engineer\nDo you love building and pionee...           160000
# 1412  Requisition ID\n531451\n\nMedidata: Power Smar...           171289
# 1885  Who We Are\nMeasured helps DTC brands grow by ...           157979
#
# ...

# %%
df.loc[2:6]
# Out:
#                       company               job title      location  \
# 2                      Notion  Data Scientist, Growth  New York, NY
# 3                  Net2Aspire      Jr. Data Scientist        Remote
# 4              Ntropy Network          Data Scientist        Remote
# 5                      PayPal          Data Scientist   Chicago, IL
# 6  Pomeroy Technologies, LLC.          Data Scientist        Remote
#
#                                      job description  salary estimate  \
# 2  About Us:\nWe're on a mission to make it possi...           137853
# 3  ? Apply Statistical and Machine Learning metho...            72500
# 4  Over the last few decades, technological innov...           155000
# 5  At PayPal (NASDAQ: PYPL), we believe that ever...           109837
# 6  Data Scientist--Remote\n(company is based in t...           110000
#
#              company_size                    company_type  \
# 2    201 to 500 Employees               Company - Private
# ...

# %%
display(df.iloc[[0, 2, 4, 7]])
# Out:
#           company                                          job title  \
# 0       Microsoft                           Data & Applied Scientist
# 2          Notion                             Data Scientist, Growth
# 4  Ntropy Network                                     Data Scientist
# 7           Delta  Associate Data Scientist, Operations Decision ...
#
#        location                                    job description  \
# 0   Redmond, WA  Microsoft 365 is a key part of the companys c...
# 2  New York, NY  About Us:\nWe're on a mission to make it possi...
# 4        Remote  Over the last few decades, technological innov...
# 7   Atlanta, GA  United States, Georgia, Atlanta\nOps Control\n...
#
#    salary estimate          company_size       company_type  \
# 0           123486      10000+ Employees   Company - Public
# 2           137853  201 to 500 Employees  Company - Private
# 4           155000     1 to 50 Employees  Company - Private
# ...

# %%
display(df.iloc[1: 5, 2: 5]) #first rows then columns
# Out:
#        location                                    job description  \
# 1        Remote  Center Information:\nThe Quantitative Biomedic...
# 2  New York, NY  About Us:\nWe're on a mission to make it possi...
# 3        Remote  ? Apply Statistical and Machine Learning metho...
# 4        Remote  Over the last few decades, technological innov...
#
#    salary estimate
# 1            93500
# 2           137853
# 3            72500
# 4           155000

# %%
# Using loc with axis=0 to select specific rows
df.loc[2:5, :]  # Select rows 2 to 5 (inclusive) and all columns
df.loc[[1, 3, 5], :]  # Select rows 1, 3, and 5 and all columns

# Using loc with axis=1 to select specific columns
df.loc[:, 'location']  # Select all rows and 'column1'
df.loc[:, ['company', 'salary estimate']]  # Select all rows and columns 'column1' and 'column2'

# Using iloc with axis=0 to select specific rows
df.iloc[2:5, :]  # Select rows 2 to 4 (exclusive) and all columns
df.iloc[[1, 3, 5], :]  # Select rows 1, 3, and 5 and all columns

# Using iloc with axis=1 to select specific columns
df.iloc[:, 0]  # Select all rows and the first column
df.iloc[:, [0, 2]]  # Select all rows and columns 0 and 2
# Out:
#                              company       location
# 0                          Microsoft    Redmond, WA
# 1     UT Southwestern Medical Center         Remote
# 2                             Notion   New York, NY
# 3                         Net2Aspire         Remote
# 4                     Ntropy Network         Remote
# ...                              ...            ...
# 2079                         YouTube  San Bruno, CA
# 2080              Hunter Engineering  Bridgeton, MO
# 2081     precision technologies corp         Remote
# 2082     Argonne National Laboratory     Lemont, IL
# 2083            Colossal Biosciences     Dallas, TX
#
# [2084 rows x 2 columns]
